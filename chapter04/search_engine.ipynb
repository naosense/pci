# %%
from search_engine import *

e = Searcher("searchindex.db")
e.get_match_rows("functional programming")
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# ([(1, 327, 23),
#   (1, 327, 162),
#   (1, 327, 243),
#   (1, 327, 261),
#   (1, 327, 269),
#   (1, 327, 436),
#   (1, 327, 953),
#   (1, 327, 1123),
#   (1, 327, 1159),
#   (1, 327, 1172),
#   (1, 327, 1230),
#   (1, 327, 1240),
#   (1, 327, 1258),
#   (1, 327, 1304),
#   (1, 327, 1346),
#   (1, 327, 1351),
#   (1, 327, 1407),
#   (1, 327, 1410),
#   (1, 327, 1603),
#   (1, 327, 1668),
#   (1, 327, 1681),
#   (1, 327, 1687),
#   (1, 327, 1690),
#   (1, 327, 1715),
#   (1, 327, 1745),
#   (1, 327, 1778),
#   (1, 327, 1857),
#   (1, 327, 1897),
#   (1, 327, 1927),
#   (1, 327, 1949),
#   (1, 327, 2042),
#   (1, 327, 2109),
#   (1, 327, 2119),
#   (1, 327, 2151),
#   (1, 327, 2386),
#   (1, 327, 2453),
#   (1, 327, 2464),
#   (1, 327, 2656),
#   (1, 327, 2761),
#   (1, 327, 2766),
#   (1, 327, 2800),
#   (1, 327, 2855),
#   (1, 327, 2995),
# ...

# %%
e.query("functional programming")
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/Functional_programming.html
# 0.26247587537910116	http://kiwitobes.com/wiki/Categorical_list_of_programming_languages.html
# 0.0623104494072236	http://kiwitobes.com/wiki/Programming_language.html
# 0.04397573752412462	http://kiwitobes.com/wiki/Lisp_programming_language.html
# 0.036393713813068655	http://kiwitobes.com/wiki/Programming_paradigm.html
# 0.030879514750482492	http://kiwitobes.com/wiki/Multi-paradigm_programming_language.html
# 0.02729528535980149	http://kiwitobes.com/wiki/Perl.html
# 0.022056796250344637	http://kiwitobes.com/wiki/Declarative_programming.html
# 0.020264681555004136	http://kiwitobes.com/wiki/Generic_programming.html
# 0.01902398676592225	http://kiwitobes.com/wiki/Object-oriented_programming.html
# ([145, 19], [220, 1, 2, 227, 289, 288, 171, 196, 293, 296])

# %%
e.query("functional programming", score_type=ScoreType.LOCATION)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/Functional_programming.html
# 0.15018315018315018	http://kiwitobes.com/wiki/Haskell_programming_language.html
# 0.14963503649635038	http://kiwitobes.com/wiki/Opal_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Joy_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Dylan_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Charity_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Curry_programming_language.html
# 0.14909090909090908	http://kiwitobes.com/wiki/Scheme_programming_language.html
# 0.14855072463768115	http://kiwitobes.com/wiki/Logo_programming_language.html
# ([145, 19], [220, 225, 232, 372, 226, 223, 221, 141, 125, 253])

# %%
e.query("functional programming", score_type=ScoreType.DISTANCE)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/XSLT.html
# 1.0	http://kiwitobes.com/wiki/XQuery.html
# 1.0	http://kiwitobes.com/wiki/Procedural_programming.html
# 1.0	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 1.0	http://kiwitobes.com/wiki/ISWIM.html
# 1.0	http://kiwitobes.com/wiki/Smalltalk_programming_language.html
# 1.0	http://kiwitobes.com/wiki/MOO_programming_language.html
# 1.0	http://kiwitobes.com/wiki/SuperCollider.html
# 1.0	http://kiwitobes.com/wiki/Smalltalk.html
# 1.0	http://kiwitobes.com/wiki/Sather_programming_language.html
# ([145, 19], [437, 436, 373, 372, 370, 365, 361, 352, 345, 342])

# %%
e.query("functional programming", score_type=ScoreType.INBOUND_COUNT)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/Programming_language.html
# 0.5190476190476191	http://kiwitobes.com/wiki/Object-oriented_programming.html
# 0.44285714285714284	http://kiwitobes.com/wiki/Unix.html
# 0.3761904761904762	http://kiwitobes.com/wiki/Functional_programming.html
# 0.3619047619047619	http://kiwitobes.com/wiki/Python_programming_language.html
# 0.3380952380952381	http://kiwitobes.com/wiki/Programming_paradigm.html
# 0.319047619047619	http://kiwitobes.com/wiki/Perl.html
# 0.29523809523809524	http://kiwitobes.com/wiki/Lisp_programming_language.html
# 0.2857142857142857	http://kiwitobes.com/wiki/Assembly_language.html
# 0.28095238095238095	http://kiwitobes.com/wiki/Smalltalk.html
# ([145, 19], [2, 296, 91, 220, 249, 289, 171, 227, 23, 345])

# %%
e.query("functional programming", score_type=ScoreType.MIX)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 2.5	http://kiwitobes.com/wiki/Functional_programming.html
# 0.4381901610933869	http://kiwitobes.com/wiki/Categorical_list_of_programming_languages.html
# 0.2659973981739441	http://kiwitobes.com/wiki/Lisp_programming_language.html
# 0.24292016227500096	http://kiwitobes.com/wiki/Haskell_programming_language.html
# 0.23948968594129885	http://kiwitobes.com/wiki/Scheme_programming_language.html
# 0.23592230973016387	http://kiwitobes.com/wiki/Logo_programming_language.html
# 0.23521618166779457	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 0.2327347920896308	http://kiwitobes.com/wiki/Dylan_programming_language.html
# 0.2312183873474196	http://kiwitobes.com/wiki/Curry_programming_language.html
# 0.2304081106675777	http://kiwitobes.com/wiki/ML_programming_language.html
# ([145, 19], [220, 1, 227, 225, 125, 253, 372, 223, 141, 230])

# %%
# e.calculate_pagerank()

# %%
e.query("functional programming", score_type=ScoreType.PAGERANK)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/Programming_language.html
# 0.3681406168880541	http://kiwitobes.com/wiki/Object-oriented_programming.html
# 0.31814547514562774	http://kiwitobes.com/wiki/Functional_programming.html
# 0.29128248354941816	http://kiwitobes.com/wiki/Unix.html
# 0.27779230759439555	http://kiwitobes.com/wiki/Programming_paradigm.html
# 0.2559290274956696	http://kiwitobes.com/wiki/Smalltalk.html
# 0.25576353104054184	http://kiwitobes.com/wiki/Assembly_language.html
# 0.240538284960497	http://kiwitobes.com/wiki/Python_programming_language.html
# 0.23482698100147828	http://kiwitobes.com/wiki/Lisp_programming_language.html
# 0.2322370967136994	http://kiwitobes.com/wiki/Haskell_programming_language.html
# ([145, 19], [2, 296, 220, 91, 289, 345, 23, 249, 227, 225])

# %%
e.query("functional programming", score_type=ScoreType.LINK_TEXT)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/Programming_language.html
# 0.8029777059337773	http://kiwitobes.com/wiki/Functional_programming.html
# 0.31189848994112374	http://kiwitobes.com/wiki/Object-oriented_programming.html
# 0.18247519690982422	http://kiwitobes.com/wiki/Programming_paradigm.html
# 0.13693299456869146	http://kiwitobes.com/wiki/Logic_programming.html
# 0.13347660125306685	http://kiwitobes.com/wiki/Procedural_programming.html
# 0.12065778869302242	http://kiwitobes.com/wiki/Imperative_programming.html
# 0.09331146730304775	http://kiwitobes.com/wiki/Generic_programming.html
# 0.04653775909382322	http://kiwitobes.com/wiki/Categorical_list_of_programming_languages.html
# 0.04423269953554726	http://kiwitobes.com/wiki/Mozart_Programming_System.html
# ([145, 19], [2, 220, 296, 289, 258, 373, 197, 293, 1, 155])

# %%
e.query("functional programming", score_type=ScoreType.NN)
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.0	http://kiwitobes.com/wiki/MOO_programming_language.html
# 0.9579599877098922	http://kiwitobes.com/wiki/Self_programming_language.html
# 0.8886138813668741	http://kiwitobes.com/wiki/XSLT.html
# 0.8780961150878906	http://kiwitobes.com/wiki/XQuery.html
# 0.7808425825596174	http://kiwitobes.com/wiki/Unified_Modeling_Language.html
# 0.7149032133275531	http://kiwitobes.com/wiki/Smalltalk_programming_language.html
# 0.6701532208265005	http://kiwitobes.com/wiki/SNOBOL.html
# 0.6551021122528298	http://kiwitobes.com/wiki/ISWIM.html
# 0.5835640995788449	http://kiwitobes.com/wiki/Procedural_programming.html
# 0.5336892517110918	http://kiwitobes.com/wiki/Miranda_programming_language.html
# ([145, 19], [361, 364, 437, 436, 419, 365, 389, 370, 373, 372])
